# %%
import hiive.mdptoolbox.mdp, hiive.mdptoolbox.example
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
np.random.seed(2)

# %%
P, R = hiive.mdptoolbox.example.forest(1000)

# %% [markdown]
# ## Value Iteration

# %%
# Value Iteration
import pandas as pd
P, R = hiive.mdptoolbox.example.forest(1000)
gamma = 0.99
vi = hiive.mdptoolbox.mdp.ValueIteration(P, R, gamma)
to_run = vi.run()
n_iter = vi.iter
state_run = pd.DataFrame(to_run)

# %%
state_run
# Out:
#    State Action     Reward     Error      Time      Max V     Mean V  \
# 0   None   None   4.000000  4.000000  0.000996   4.000000   1.002000
# 1   None   None   7.564000  3.564000  0.002994   7.564000   1.009019
# 2   None   None  10.827733  3.175524  0.004008  10.827733   1.896460
# 3   None   None  13.744452  2.829392  0.004988  13.744452   1.994018
# 4   None   None  16.421921  2.520988  0.006981  16.421921   2.787776
# ..   ...    ...        ...       ...       ...        ...        ...
# 87  None   None  59.930408  0.000174  0.110225  59.930408  28.292586
# 88  None   None  60.126152  0.000155  0.112220  60.126152  28.488216
# 89  None   None  60.319924  0.000138  0.113222  60.319924  28.681852
# 90  None   None  60.511748  0.000123  0.115213  60.511748  28.873585
# 91  None   None  60.701641  0.000110  0.116210  60.701641  29.063370
#
#     Iteration
# 0           1
# 1           2
# 2           3
# 3           4
# 4           5
# ..        ...
# 87         88
# ...

# %%
algo = 'Forest - Value Iterations:'
fig, ax = plt.subplots()
ax.plot(state_run['Iteration'] , state_run['Max V'], "r-")
ax.set_xlabel('Iterations')
ax.set_ylabel('Max V')
ax.set_title(f'{algo} Convergence Criteria')
# ax.legend()
plt.show(fig)

fig, ax = plt.subplots()
ax.plot(state_run['Iteration'] , state_run['Mean V'], "r-")
ax.set_xlabel('Iterations')
ax.set_ylabel('Avg V')
ax.set_title(f'{algo} Convergence Criteria')
# ax.legend()
plt.show(fig)

fig, ax = plt.subplots()
ax.plot(state_run['Iteration'] , state_run['Error'], "r-")
ax.set_xlabel('Iterations')
ax.set_ylabel('Errors')
ax.set_title(f'{algo} Convergence Criteria')
# ax.legend()
plt.show(fig)

fig, ax = plt.subplots()
ax.plot(state_run['Iteration'] , state_run['Time'], "b-")
ax.set_xlabel('Iterations')
ax.set_ylabel('Computation Time')
ax.set_title(f'{algo} Time and Iterations to Converge')
# ax.legend()
plt.show(fig)

# %%
# Value Iteration!!
gamma = 0.99 
to_loop = np.arange(0.1, 1 , 0.01)
# P, R = hiive.mdptoolbox.example.forest(1000)
# 4x4 !! 
vi_util_opt_pol = []
vi_num_iterations = []
vi_time_taken_list = []
vi_rewards_list = []
for i in to_loop:
    print("Discount Factor(gamma):", i)
    vi = hiive.mdptoolbox.mdp.ValueIteration(P, R, i)
    vi.run()
    vi_rewards_list.append([np.max(vi.V), np.mean(vi.V)])
    vi_util_opt_pol.append(vi.policy)
    vi_num_iterations.append(vi.iter)
    vi_time_taken_list.append(vi.time)
    print("Utility of optimal policy:" ,(np.max(vi.V), np.mean(vi.V)), "Time Taken:", vi.time, 'Num Iterations:', vi.iter)
# Out:
# Discount Factor(gamma): 0.1
# Utility of optimal policy: (4.36, 1.00245) Time Taken: 0.00299072265625 Num Iterations: 2
# Discount Factor(gamma): 0.11
# Utility of optimal policy: (4.396, 1.002495) Time Taken: 0.0029897689819335938 Num Iterations: 2
# Discount Factor(gamma): 0.12
# Utility of optimal policy: (4.432, 1.00254) Time Taken: 0.001994609832763672 Num Iterations: 2
# Discount Factor(gamma): 0.13
# Utility of optimal policy: (4.468, 1.002585) Time Taken: 0.0019919872283935547 Num Iterations: 2
# Discount Factor(gamma): 0.13999999999999999
# Utility of optimal policy: (4.569268, 1.0203017520000002) Time Taken: 0.003988742828369141 Num Iterations: 3
# Discount Factor(gamma): 0.14999999999999997
# Utility of optimal policy: (4.6149249999999995, 1.0229614500000004) Time Taken: 0.003987789154052734 Num Iterations: 3
# Discount Factor(gamma): 0.15999999999999998
# Utility of optimal policy: (4.661248, 1.025801472) Time Taken: 0.003989458084106445 Num Iterations: 3
# ...

# %%
import matplotlib.pyplot as plt
algo = 'Forest - Value Iterations:'
fig, ax = plt.subplots()
ax.plot(list(to_loop) , [i[0] for i in vi_rewards_list], "g-")
ax.set_xlabel('Discount Factor(Gamma)')
ax.set_ylabel('Utilities (Rewards)')
ax.set_title(f'{algo} Utilities vs Discount Factor')
# ax.legend()
plt.show(fig)

fig, ax = plt.subplots()
ax.plot(list(to_loop) , [i[1] for i in vi_rewards_list], "g-")
ax.set_xlabel('Discount Factor(Gamma)')
ax.set_ylabel('Utilities (Rewards)')
ax.set_title(f'{algo} Utilities (Avg) vs Discount Factor')
# ax.legend()
plt.show(fig)


fig, ax = plt.subplots()
ax.plot(list(to_loop) , vi_num_iterations, "b-")
ax.set_xlabel('Discount Factor(Gamma)')
ax.set_ylabel('Number of Iterations')
ax.set_title(f'{algo} Number of Iterations vs Discount Factor')
# ax.legend()
plt.show(fig)

fig, ax = plt.subplots()
ax.plot(list(to_loop) , vi_time_taken_list, "r-")
ax.set_xlabel('Discount Factor(Gamma)')
ax.set_ylabel('Time Taken (Seconds)')
ax.set_title(f'{algo} Time Taken (Seconds) vs Discount Factor')
# ax.legend()
plt.show(fig)

# %% [markdown]
# ### Value Iteraions with different sizes

# %%
gamma = 0.99
size_to_loop = np.arange(1000, 10001, 1000)

# 4x4 !! 
vi_size_util_opt_pol = []
vi_size_num_iterations = []
vi_size_time_taken_list = []
vi_size_rewards_list = []
vi_size_error_list = []

for i in size_to_loop:
    print("Forest Size:", i)
    P, R = hiive.mdptoolbox.example.forest(i)
    vi = hiive.mdptoolbox.mdp.ValueIteration(P, R, gamma)
    vi.run()
    vi_size_rewards_list.append([np.max(vi.V), np.mean(vi.V)])
    vi_size_util_opt_pol.append(vi.policy)
    vi_size_num_iterations.append(vi.iter)
    vi_size_time_taken_list.append(vi.time)
    vi_size_error_list.append(vi.error_mean)
    print("Utility of optimal policy:" ,(np.max(vi.V), np.mean(vi.V)), "Time Taken:", vi.time, 'Num Iterations:', vi.iter)
# Out:
# Forest Size: 1000
# Utility of optimal policy: (60.701641491614865, 29.063370347664677) Time Taken: 0.12067246437072754 Num Iterations: 92
# Forest Size: 2000
# Utility of optimal policy: (60.701641491614865, 28.96005496544444) Time Taken: 0.5966360569000244 Num Iterations: 92
# Forest Size: 3000
# Utility of optimal policy: (60.701641491614865, 28.925616504704358) Time Taken: 1.0382459163665771 Num Iterations: 92
# Forest Size: 4000
# Utility of optimal policy: (60.701641491614865, 28.908397274334327) Time Taken: 1.8605060577392578 Num Iterations: 92
# Forest Size: 5000
# Utility of optimal policy: (60.701641491614865, 28.898065736112294) Time Taken: 2.6813032627105713 Num Iterations: 92
# Forest Size: 6000
# Utility of optimal policy: (60.701641491614865, 28.89117804396428) Time Taken: 3.8760740756988525 Num Iterations: 92
# Forest Size: 7000
# Utility of optimal policy: (60.701641491614865, 28.886258263858558) Time Taken: 5.234563589096069 Num Iterations: 92
# Forest Size: 8000
# ...

# %%
import matplotlib.pyplot as plt
algo = 'Value Iterations - Forest:'
fig, ax = plt.subplots()
ax.plot(list(size_to_loop) , [i[0] for i in vi_size_rewards_list], "g-")
ax.set_xlabel('Size of the problems')
ax.set_ylabel('Utilities (Rewards)')
ax.set_title(f'{algo} Utilities(MAX) vs Sizes')
# ax.legend()
plt.show(fig)

fig, ax = plt.subplots()
ax.plot(list(size_to_loop) , [i[1] for i in vi_size_rewards_list], "b-")
ax.set_xlabel('State Sizes')
ax.set_ylabel('Utilities (Rewards)')
ax.set_title(f'{algo} Utilities(AVG) vs Sizes')
# ax.legend()
plt.show(fig)

fig, ax = plt.subplots()
ax.plot(list(size_to_loop) , vi_size_num_iterations, "b-")
ax.set_xlabel('State Sizes')
ax.set_ylabel('Number of Iterations')
ax.set_title(f'{algo} Number of Iterations vs Sizes')
# ax.legend()
plt.show(fig)

fig, ax = plt.subplots()
ax.plot(list(size_to_loop) , vi_size_time_taken_list, "r-")
ax.set_xlabel('State Sizes')
ax.set_ylabel('Time Taken (Seconds)')
ax.set_title(f'{algo} Time Taken (Seconds) vs Sizes')
# ax.legend()
plt.show(fig)

fig, ax = plt.subplots()
ax.plot(list(size_to_loop) , vi_size_error_list, "r-")
ax.set_xlabel('State Sizes')
ax.set_ylabel('Time Taken (Seconds)')
ax.set_title(f'{algo} Error vs Sizes')
# ax.legend()
plt.show(fig)

# %% [markdown]
# ## Policy Iteration

# %%
# Policy Iteration
P, R = hiive.mdptoolbox.example.forest(1000)
gamma = 0.9
pi = hiive.mdptoolbox.mdp.PolicyIteration(P, R, gamma)
pi_to_run = pi.run()
# n_iter = pi.iter
pi_state_run = pd.DataFrame(pi_to_run)

# %%
import matplotlib.pyplot as plt
algo = 'Forest - Policy Iterations:'
fig, ax = plt.subplots()
ax.plot(pi_state_run['Iteration'] , pi_state_run['Error'], "r-")
ax.set_xlabel('Iterations')
ax.set_ylabel('Errors')
ax.set_title(f'{algo} Convergence Criteria')
# ax.legend()
plt.show(fig)

fig, ax = plt.subplots()
ax.plot(pi_state_run['Iteration'] , pi_state_run['Time'], "b-")
ax.set_xlabel('Iterations')
ax.set_ylabel('Computation Time')
ax.set_title(f'{algo} Time and Iterations to Converge')
# ax.legend()
plt.show(fig)

# %%
# Policy Iteration!!
gamma = 0.9
to_loop = np.arange(0.1, 1 , 0.01)
P, R = hiive.mdptoolbox.example.forest(1000)
# 4x4 !! 
pi_util_opt_pol = []
pi_num_iterations = []
pi_time_taken_list = []
pi_rewards_list = []
for i in to_loop:
    print("Discount Factor(gamma):", i)
    pi = hiive.mdptoolbox.mdp.PolicyIteration(P, R, i)
    pi.run()
    pi_rewards_list.append([np.max(pi.V), np.mean(pi.V)])
    pi_util_opt_pol.append(pi.policy)
    pi_num_iterations.append(pi.iter)
    pi_time_taken_list.append(pi.time)
    print("Utility of optimal policy:" ,(np.max(pi.V), np.mean(pi.V)), "Time Taken:", pi.time, 'Num Iterations:', pi.iter)
# Out:
# Discount Factor(gamma): 0.1
# Utility of optimal policy: (4.396612561750176, 1.0116443189837685) Time Taken: 0.04288530349731445 Num Iterations: 1
# Discount Factor(gamma): 0.11
# Utility of optimal policy: (4.440747360384749, 1.0136534126025358) Time Taken: 0.04188990592956543 Num Iterations: 1
# Discount Factor(gamma): 0.12
# Utility of optimal policy: (4.485795040626595, 1.0158617385916604) Time Taken: 0.03889751434326172 Num Iterations: 1
# Discount Factor(gamma): 0.13
# Utility of optimal policy: (4.531783865192692, 1.018272406839292) Time Taken: 0.030915021896362305 Num Iterations: 1
# Discount Factor(gamma): 0.13999999999999999
# Utility of optimal policy: (4.578743291283109, 1.0208887932726949) Time Taken: 0.03390908241271973 Num Iterations: 1
# Discount Factor(gamma): 0.14999999999999997
# Utility of optimal policy: (4.626704033960099, 1.0237145506263414) Time Taken: 0.03092503547668457 Num Iterations: 1
# Discount Factor(gamma): 0.15999999999999998
# ...

# %%
algo = 'Policy Iterations:'
fig, ax = plt.subplots()
ax.plot(list(to_loop) , [i[0] for i in pi_rewards_list], "g-")
ax.set_xlabel('Discount Factor(Gamma)')
ax.set_ylabel('Utilities (Rewards)')
ax.set_title(f'{algo} Utilities vs Discount Factor')
# ax.legend()
plt.show(fig)

fig, ax = plt.subplots()
ax.plot(list(to_loop) , [i[1] for i in pi_rewards_list], "g-")
ax.set_xlabel('Discount Factor(Gamma)')
ax.set_ylabel('Utilities (Rewards)')
ax.set_title(f'{algo} Utilities (Avg Rewards) vs Discount Factor')
# ax.legend()
plt.show(fig)

fig, ax = plt.subplots()
ax.plot(list(to_loop) , pi_num_iterations, "b-")
ax.set_xlabel('Discount Factor(Gamma)')
ax.set_ylabel('Number of Iterations')
ax.set_title(f'{algo} Number of Iterations vs Discount Factor')
# ax.legend()
plt.show(fig)

fig, ax = plt.subplots()
ax.plot(list(to_loop) , pi_time_taken_list, "r-")
ax.set_xlabel('Discount Factor(Gamma)')
ax.set_ylabel('Time Taken (Seconds)')
ax.set_title(f'{algo} Time Taken (Seconds) vs Discount Factor')
# ax.legend()
plt.show(fig)

# %%
algo = 'VI vs PI:'
fig, ax = plt.subplots()
ax.plot(list(to_loop) , [i[0] for i in vi_rewards_list], "b-", label='Value Iterations')
ax.plot(list(to_loop) , [i[0] for i in pi_rewards_list], "g-", label='Policy Iterations')

ax.set_xlabel('Discount Factor(Gamma)')
ax.set_ylabel('Utilities (Rewards)')
ax.set_title(f'{algo} Utilities vs Discount Factor')
ax.legend()
plt.show(fig)

fig, ax = plt.subplots()
ax.plot(list(to_loop) , [i[1] for i in vi_rewards_list], "b-", label='Value Iterations')
ax.plot(list(to_loop) , [i[1] for i in pi_rewards_list], "g-", label='Policy Iterations')
ax.set_xlabel('Discount Factor(Gamma)')
ax.set_ylabel('Utilities (Rewards)')
ax.set_title(f'{algo} Utilities (Avg Rewards) vs Discount Factor')
ax.legend()
plt.show(fig)

fig, ax = plt.subplots()
ax.plot(list(to_loop) , vi_num_iterations, "b-", label='Value Iterations')
ax.plot(list(to_loop) , pi_num_iterations, "g-", label='Policy Iterations')
ax.set_xlabel('Discount Factor(Gamma)')
ax.set_ylabel('Number of Iterations')
ax.set_title(f'{algo} Number of Iterations vs Discount Factor')
ax.legend()
plt.show(fig)

fig, ax = plt.subplots()
ax.plot(list(to_loop) , vi_time_taken_list, "b-", label='Value Iteration')
ax.plot(list(to_loop) , pi_time_taken_list, "g-", label='Policy Iterations')
ax.set_xlabel('Discount Factor(Gamma)')
ax.set_ylabel('Time Taken (Seconds)')
ax.set_title(f'{algo} Time Taken (Seconds) vs Discount Factor')
ax.legend()
plt.show(fig)

# %% [markdown]
# ### Policy Iterations with increasing sizes:

# %%
gamma = 0.99
size_to_loop = np.arange(1000, 10001, 1000)

# 4x4 !! 
pi_size_util_opt_pol = []
pi_size_num_iterations = []
pi_size_time_taken_list = []
pi_size_rewards_list = []
pi_size_error_list = []

for i in size_to_loop:
    print("Forest Size:", i)
    P, R = hiive.mdptoolbox.example.forest(i)
    pi = hiive.mdptoolbox.mdp.PolicyIteration(P, R, gamma)
    pi.run()
    pi_size_rewards_list.append([np.max(pi.V), np.mean(pi.V)])
    pi_size_util_opt_pol.append(pi.policy)
    pi_size_num_iterations.append(pi.iter)
    pi_size_time_taken_list.append(pi.time)
    pi_size_error_list.append(pi.error_mean)
    print("Utility of optimal policy:" ,(np.max(pi.V), np.mean(pi.V)), "Time Taken:", pi.time, 'Num Iterations:', pi.iter)
# Out:
# Forest Size: 1000
# Utility of optimal policy: (79.49242913074468, 47.85339253446561) Time Taken: 0.693511962890625 Num Iterations: 18
# Forest Size: 2000
# Utility of optimal policy: (79.49242913074468, 47.75007014348863) Time Taken: 3.054391384124756 Num Iterations: 18
# Forest Size: 3000
# Utility of optimal policy: (79.49242913074468, 47.71562934649632) Time Taken: 8.402514457702637 Num Iterations: 18
# Forest Size: 4000
# Utility of optimal policy: (79.49242913074468, 47.69840894800013) Time Taken: 16.8168306350708 Num Iterations: 18
# Forest Size: 5000
# Utility of optimal policy: (79.49242913074468, 47.68807670890245) Time Taken: 27.950189352035522 Num Iterations: 18
# Forest Size: 6000
# Utility of optimal policy: (79.49242913074468, 47.68118854950399) Time Taken: 60.094274044036865 Num Iterations: 18
# Forest Size: 7000
# Utility of optimal policy: (79.49242913074468, 47.67626843564793) Time Taken: 75.11061191558838 Num Iterations: 18
# Forest Size: 8000
# ...

# %%
fig, ax = plt.subplots()
ax.plot(list(size_to_loop) , pi_size_error_list, "b-")
ax.set_xlabel('Discount Factor(Gamma)')
ax.set_ylabel('Mean Error')
ax.set_title(f'{algo} Mean Errors vs Discount Factor')
# ax.legend()
plt.show(fig)

# %%
algo = 'Policy Iterations - Forest:'
fig, ax = plt.subplots()
ax.plot(list(size_to_loop) , [i[0] for i in pi_size_rewards_list], "g-")
ax.set_xlabel('Size of the problems')
ax.set_ylabel('Utilities (Rewards)')
ax.set_title(f'{algo} Utilities(MAX) vs Sizes')
# ax.legend()
plt.show(fig)

fig, ax = plt.subplots()
ax.plot(list(size_to_loop) , [i[1] for i in pi_size_rewards_list], "g-")
ax.set_xlabel('State Sizes')
ax.set_ylabel('Utilities (Rewards)')
ax.set_title(f'{algo} Utilities(AVG) vs Sizes')
# ax.legend()
plt.show(fig)

fig, ax = plt.subplots()
ax.plot(list(size_to_loop) , pi_size_num_iterations, "b-")
ax.set_xlabel('Size of the problems')
ax.set_ylabel('Number of Iterations')
ax.set_title(f'{algo} Number of Iterations vs Sizes')
# ax.legend()
plt.show(fig)

fig, ax = plt.subplots()
ax.plot(list(size_to_loop) , pi_size_time_taken_list, "r-")
ax.set_xlabel('Size of the problems')
ax.set_ylabel('Time Taken (Seconds)')
ax.set_title(f'{algo} Time Taken (Seconds) vs Sizes')
# ax.legend()
plt.show(fig)

fig, ax = plt.subplots()
ax.plot(list(size_to_loop) , pi_size_error_list, "r-")
ax.set_xlabel('Size of the problems')
ax.set_ylabel('Time Taken (Seconds)')
ax.set_title(f'{algo} Error vs Sizes')
# ax.legend()
plt.show(fig)

# %%
algo = 'VI vs PI:'
fig, ax = plt.subplots()
ax.plot(list(size_to_loop) , [i[0] for i in vi_size_rewards_list], "b-", label='Value Iterations')
ax.plot(list(size_to_loop) , [i[0] for i in pi_size_rewards_list], "g-", label='Policy Iterations')

ax.set_xlabel('State Sizes')
ax.set_ylabel('Utilities (Rewards)')
ax.set_title(f'{algo} Utilities vs Discount Factor')
ax.legend()
plt.show(fig)

fig, ax = plt.subplots()
ax.plot(list(size_to_loop) , [i[1] for i in vi_size_rewards_list], "b-", label='Value Iterations')
ax.plot(list(size_to_loop) , [i[1] for i in pi_size_rewards_list], "g-", label='Policy Iterations')
ax.set_xlabel('State Sizes')
ax.set_ylabel('Utilities (Rewards)')
ax.set_title(f'{algo} Utilities (Avg Rewards) vs Discount Factor')
ax.legend()
plt.show(fig)

fig, ax = plt.subplots()
ax.plot(list(size_to_loop) , vi_size_num_iterations, "b-", label='Value Iterations')
ax.plot(list(size_to_loop) , pi_size_num_iterations, "g-", label='Policy Iterations')
ax.set_xlabel('State Sizes')
ax.set_ylabel('Number of Iterations')
ax.set_title(f'{algo} Number of Iterations vs Discount Factor')
ax.legend()
plt.show(fig)

fig, ax = plt.subplots()
ax.plot(list(size_to_loop) , vi_size_time_taken_list, "b-", label='Value Iteration')
ax.plot(list(size_to_loop) , pi_size_time_taken_list, "g-", label='Policy Iterations')
ax.set_xlabel('State Sizes')
ax.set_ylabel('Time Taken (Seconds)')
ax.set_title(f'{algo} Time Taken (Seconds) vs Discount Factor')
ax.legend()
plt.show(fig)

# %% [markdown]
# ## Q Learning

# %%
# Q Learning
gamma = 0.9
ql = hiive.mdptoolbox.mdp.QLearning(P, R, gamma, epsilon=0.99, epsilon_decay=0.99, n_iter=1000000)
run_stat_ql = ql.run()
ql_state_run = pd.DataFrame(run_stat_ql)

# %%
algo = 'Forest - Q Learning:'
fig, ax = plt.subplots()
ax.plot(ql_state_run['Iteration'] , ql_state_run['Error'], "r-")
ax.set_xlabel('Iterations')
ax.set_ylabel('Errors')
ax.set_title(f'{algo} Convergence Criteria')
# ax.legend()
plt.show(fig)

fig, ax = plt.subplots()
ax.plot(ql_state_run['Iteration'] , ql_state_run['Time'], "b-")
ax.set_xlabel('Iterations')
ax.set_ylabel('Computation Time')
ax.set_title(f'{algo} Time and Iterations to Converge')
# ax.legend()
plt.show(fig)

fig, ax = plt.subplots()
ax.plot(ql_state_run['Iteration'] , ql_state_run['Max V'], "b-")
ax.set_xlabel('Iterations')
ax.set_ylabel('Computation Time')
ax.set_title(f'{algo} Max Rewards and Iterations to Converge')
plt.show(fig)

fig, ax = plt.subplots()
ax.plot(ql_state_run['Iteration'] , ql_state_run['Mean V'], "b-")
ax.set_xlabel('Iterations')
ax.set_ylabel('Computation Time')
ax.set_title(f'{algo} Mean Rewards and Iterations to Converge')
plt.show(fig)

# %%
# Q Learning!
gamma = 0.9
epsilon = 0.9
to_loop = np.arange(0.1, 1 , 0.1)
P, R = hiive.mdptoolbox.example.forest(1000)
# 4x4 !! 
util_opt_pol = []
error_list = []
time_taken_list = []
rewards_list = []
for i in to_loop:
    print("Epsilon:", i)
    ql = hiive.mdptoolbox.mdp.QLearning(P, R, gamma, epsilon=i, epsilon_decay=0.999, n_iter=100000)
    ql.run()
    rewards_list.append([np.max(ql.V), np.mean(ql.V)])
    util_opt_pol.append(ql.policy)
    time_taken_list.append(ql.time)
    error_list.append(ql.error_mean)
    print("Utility of optimal policy:" ,(np.max(ql.V), np.mean(ql.V)), "Time Taken:", ql.time)
# Out:
# Epsilon: 0.1
# Utility of optimal policy: (3.270027442020221, 0.013153866045883639) Time Taken: 7.647332668304443
# Epsilon: 0.2
# Utility of optimal policy: (3.271385555862296, 0.013284835936211369) Time Taken: 7.3256471157073975
# Epsilon: 0.30000000000000004
# Utility of optimal policy: (4.979476464127076, 0.018190914262577504) Time Taken: 7.13712477684021
# Epsilon: 0.4
# Utility of optimal policy: (4.978734863524153, 0.019734810668259883) Time Taken: 6.958838701248169
# Epsilon: 0.5
# Utility of optimal policy: (4.984693016338974, 0.01803621822461732) Time Taken: 7.456778287887573
# Epsilon: 0.6
# Utility of optimal policy: (4.976736336130081, 0.018416594529896364) Time Taken: 7.322316884994507
# Epsilon: 0.7000000000000001
# Utility of optimal policy: (4.977912517863313, 0.01791401641131885) Time Taken: 7.8358118534088135
# Epsilon: 0.8
# Utility of optimal policy: (4.98217609393376, 0.018302343762211726) Time Taken: 8.128971099853516
# Epsilon: 0.9
# ...

# %%
algo = 'QLearning:'
fig, ax = plt.subplots()
ax.plot(list(to_loop) , [i[0] for i in rewards_list], "g-")
ax.set_xlabel('Epsilon')
ax.set_ylabel('Utilities (Rewards)')
ax.set_title(f'{algo} Utilities vs different Epsilon')
# ax.legend()
plt.show(fig)

fig, ax = plt.subplots()
ax.plot(list(to_loop) , [i[1] for i in rewards_list], "g-")
ax.set_xlabel('Epsilon')
ax.set_ylabel('Utilities (Rewards)')
ax.set_title(f'{algo} Utilities (AVG) vs different Epsilon')
# ax.legend()
plt.show(fig)

fig, ax = plt.subplots()
ax.plot(list(to_loop) , error_list, "b-")
ax.set_xlabel('Epsilon')
ax.set_ylabel('Mean Error')
ax.set_title(f'{algo} Mean Errors vs different Epsilon')
# ax.legend()
plt.show(fig)

fig, ax = plt.subplots()
ax.plot(list(to_loop) , time_taken_list, "r-")
ax.set_xlabel('Epsilon')
ax.set_ylabel('Time Taken (Seconds)')
ax.set_title(f'{algo} Time Taken (Seconds) vs different Epsilon')
# ax.legend()
plt.show(fig)

# %% [markdown]
# ### Alpha

# %%
# Q Learning!
gamma = 0.9
epsilon = 0.4
to_loop = np.arange(0.1, 1 , 0.1)
P, R = hiive.mdptoolbox.example.forest(1000)
# 4x4 !! 
alpha_util_opt_pol = []
alpha_error_list = []
alpha_time_taken_list = []
alpha_rewards_list = []
for i in to_loop:
    print("Alpha:", i)
    ql = hiive.mdptoolbox.mdp.QLearning(P, R, gamma, alpha=i, epsilon=epsilon, epsilon_decay=0.999, n_iter=100000)
    ql.run()
    alpha_rewards_list.append([np.max(ql.V), np.mean(ql.V)])
    alpha_util_opt_pol.append(ql.policy)
    alpha_time_taken_list.append(ql.time)
    alpha_error_list.append(ql.error_mean)
    print("Utility of optimal policy:" ,(np.max(ql.V), np.mean(ql.V)), "Time Taken:", ql.time)
# Out:
# Alpha: 0.1
# Utility of optimal policy: (4.980822088295252, 0.01809116553046353) Time Taken: 8.819217681884766
# Alpha: 0.2
# Utility of optimal policy: (4.993693365281698, 0.01910997833714839) Time Taken: 8.58785080909729
# Alpha: 0.30000000000000004
# Utility of optimal policy: (4.992213722143158, 0.019624671289464657) Time Taken: 8.304696321487427
# Alpha: 0.4
# Utility of optimal policy: (5.014281947984339, 0.021330022113931608) Time Taken: 7.938037157058716
# Alpha: 0.5
# Utility of optimal policy: (5.012682994083006, 0.023529155404142812) Time Taken: 9.173412561416626
# Alpha: 0.6
# Utility of optimal policy: (5.011899703786753, 0.021543121242847227) Time Taken: 8.048938274383545
# Alpha: 0.7000000000000001
# Utility of optimal policy: (5.027795577049413, 0.02302651056773554) Time Taken: 7.968188047409058
# Alpha: 0.8
# Utility of optimal policy: (5.023035373619309, 0.022267363798971374) Time Taken: 7.486846685409546
# Alpha: 0.9
# ...

# %%
algo = 'QLearning:'
fig, ax = plt.subplots()
ax.plot(list(to_loop) , [i[0] for i in alpha_rewards_list], "g-")
ax.set_xlabel('Learning Rates')
ax.set_ylabel('Utilities (Rewards)')
ax.set_title(f'{algo} Utilities vs different Learning Rates')
# ax.legend()
plt.show(fig)

fig, ax = plt.subplots()
ax.plot(list(to_loop) , [i[1] for i in alpha_rewards_list], "g-")
ax.set_xlabel('Learning Rates')
ax.set_ylabel('Utilities (Rewards)')
ax.set_title(f'{algo} Utilities (AVG) vs different Learning Rates')
# ax.legend()
plt.show(fig)

fig, ax = plt.subplots()
ax.plot(list(to_loop) , alpha_error_list, "b-")
ax.set_xlabel('Learning Rates')
ax.set_ylabel('Mean Error')
ax.set_title(f'{algo} Mean Errors vs different Learning Rates')
# ax.legend()
plt.show(fig)

fig, ax = plt.subplots()
ax.plot(list(to_loop) , alpha_time_taken_list, "r-")
ax.set_xlabel('Learning Rates')
ax.set_ylabel('Time Taken (Seconds)')
ax.set_title(f'{algo} Time Taken (Seconds) vs different Learning Rates')
# ax.legend()
plt.show(fig)

# %% [markdown]
# ### Optimal Policy

# %% [markdown]
# ### Q Learning

# %%
gamma = 0.99
ql = hiive.mdptoolbox.mdp.QLearning(P, R, gamma, alpha=0.9, epsilon=0.4, epsilon_decay=0.999, n_iter=100000)
ql_run_stat = ql.run()

# %%
action_mapping_n = {0:'W', 1:'C'}
new_cnt = 0
def cumulative_cut_plot_policy(policy):
    new_cnt = 0
    new_text_sum = ""
    for i in policy:
        if new_cnt % 100 == 0:
            new_text_sum += "\n"
        new_text_sum += action_mapping_n[i]
        new_cnt +=1
    return new_text_sum

# %%
print(cumulative_cut_plot_policy(ql.policy))
# Out:
# WCWCWWCWWCWWWWWCWWWWWCWWWWWCWWWWWWWWWCWCWWWCWWWWWWCCWWWCWWWCWWWCWWWWWWWWWCWWWWWCCWWWWWWWWWCCCWWWWWWC
# WWWWWWWWWWWWWWWWWWWCWWWWWWCWWWWWWWWWWWCCWWWWWCWWWWWWWCCWWWWWWCWWWWWCCWCCWWWWCWWCCCWWWCWWCWWWWWWCCWWW
# WWWCWWWCWWWWCWWWWWWWWWCWWWWWCCWCWWCWCWWWWWWCWWWWWWWCWCWWWWWWWWWWWWWWWWWCWCWWCWWWWWCWWWWWWWWWWCWWWWCW
# WCWWCWWWWWCWWWWWWWCCWWWWWWWWWWWWWWWWCWWWWWWWCCWWWWWWWWCWWWWWWWWCWCWWWWWWWWWWWWWWWCWWWWWWWCWWWWCWWWWC
# WWWWWCWWWWWWWWWWWWCWWWWWWWWWCWWWWWWWWCCWWWWWWCWCWWWWWWWWWCCWWCCWWWWWWCWWWWCWCWWWWWCWWWWWWWWCWCWWWWCW
# WWWWWCWCWWWWWCWWWWWWWWWWCWCWWWWCWWWWWWWWWWWWCWWWWCWWWWWWCWWWWCWWWWWCCWWWWWWWWCWWCWWWWWWWWCWWWWWCWWWC
# WWWWWCWWCWWWWWWWWWWWWWWWWWWWWCWWWWWWWWWWWWCWWWCWWWCWWWWWWWWWCWWWWWCWWWWWWWWCWWWWCWWWWWCWWWWWWWWWWCWW
# WWWWCWWWWWWWWWWWWWWWWCWWWWWWWWWWWWWWWWWCWWWWWWCWWWWWWWCWWWWWWCWWWWWWWWWWWCWWWWWWWWWWWCCWWWWCWWWWWWWW
# WWWCWWWWWCWWCWWWWWCWWWWWCWWWCWWWWWWWWWCWWWCWWWWCWWWWWWWCWWWWWWWWWWWWWWWWCWWWWWCWCWWCWWWWWCWWCWWWWWWW
# ...

# %%
print(np.max(ql.V), np.mean(ql.V), ql.time)
# Out:
# 5.024932731430605 0.02356445148700446 7.4606993198394775

# %%
"Cut Action", np.sum(list(ql.policy)), 1000 - np.sum(list(ql.policy))
# Out:
# ('Cut Action', 168, 832)

# %% [markdown]
# ### Policy Iterations

# %%
gamma = 0.99
pi = hiive.mdptoolbox.mdp.PolicyIteration(P, R, gamma)
pi_run = pi.run()

# %%
print(cumulative_cut_plot_policy(pi.policy))
# Out:
# WCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCC
# CCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCC
# CCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCC
# CCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCC
# CCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCC
# CCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCC
# CCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCC
# CCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCC
# CCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCC
# ...

# %%
print(np.max(pi.V), np.mean(pi.V), pi.time)
# Out:
# 79.49242913074468 47.85339253446561 0.9012207984924316

# %%
"Cut Action", np.sum(list(pi.policy))
# Out:
# ('Cut Action', 981)

# %% [markdown]
# ## Value Iterations

# %%
gamma = 0.99
vi = hiive.mdptoolbox.mdp.ValueIteration(P, R, gamma)
vi_run = vi.run()

# %%
print(cumulative_cut_plot_policy(vi.policy))
# Out:
# WCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCC
# CCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCC
# CCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCC
# CCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCC
# CCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCC
# CCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCC
# CCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCC
# CCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCC
# CCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCC
# ...

# %%
print(np.max(vi.V), np.mean(vi.V), vi.time)
# Out:
# 60.701641491614865 29.063370347664677 0.09439802169799805

# %%
"Cut Action", np.sum(list(vi.policy))
# Out:
# ('Cut Action', 981)
